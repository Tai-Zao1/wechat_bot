# %%
from pyweixin import Navigator
Navigator.open_weixin()

# %%
from pyweixin import Navigator
Navigator.open_dialog_window(friend='1314xxxxxx')#电话号打开好友界面

# %%
from pyweixin import AutoReply,Navigator
def reply_func2(newMessage:str,contexts:list[str]):#
    return '自动回复[微信机器人]:您好,我当前不在,请您稍后再试'
main_window=Navigator.open_dialog_window(friend='小号测试')
AutoReply.auto_reply_to_friend(dialog_window=main_window,duration='30s',callback=reply_func2)

# %%
from pyweixin import Messages
newMessages=Messages.dump_chat_history('小号测试',28,capture_alia=True)
newMessages

# %%
from pyweixin import Collections
Collections.collect_offAcc_articles(name='新华社',number=20)

# %%
from pyweixin import Navigator,Monitor
dialog_window=Navigator.open_seperate_dialog_window(friend='小号测试')
Monitor.listen_on_chat(dialog_window=dialog_window,duration='20s',save_photo=True)
